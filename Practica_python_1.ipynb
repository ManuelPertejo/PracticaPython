# %%
! pip install pandas
# Out:
# Collecting pandas
#   Using cached https://files.pythonhosted.org/packages/db/83/7d4008ffc2988066ff37f6a0bb6d7b60822367dcb36ba5e39aa7801fda54/pandas-0.24.2-cp27-cp27mu-manylinux1_x86_64.whl
# Collecting numpy>=1.12.0 (from pandas)
#   Using cached https://files.pythonhosted.org/packages/d7/b1/3367ea1f372957f97a6752ec725b87886e12af1415216feec9067e31df70/numpy-1.16.5-cp27-cp27mu-manylinux1_x86_64.whl
# Collecting pytz>=2011k (from pandas)
#   Using cached https://files.pythonhosted.org/packages/e7/f9/f0b53f88060247251bf481fa6ea62cd0d25bf1b11a87888e53ce5b7c8ad2/pytz-2019.3-py2.py3-none-any.whl
# Collecting python-dateutil>=2.5.0 (from pandas)
#   Using cached https://files.pythonhosted.org/packages/d4/70/d60450c3dd48ef87586924207ae8907090de0b306af2bce5d134d78615cb/python_dateutil-2.8.1-py2.py3-none-any.whl
# Collecting six>=1.5 (from python-dateutil>=2.5.0->pandas)
#   Using cached https://files.pythonhosted.org/packages/65/26/32b8464df2a97e6dd1b656ed26b2c194606c16fe163c695a992b36c11cdf/six-1.13.0-py2.py3-none-any.whl
# Installing collected packages: numpy, pytz, six, python-dateutil, pandas
# Successfully installed numpy-1.16.5 pandas-0.24.2 python-dateutil-2.8.1 pytz-2019.3 six-1.13.0

# %%
import pandas as pd
import numpy as np
import seaborn as sns

# %%
pd.set_option('display.max_columns', 500)
mundo = pd.read_csv("mundo.csv", encoding = "UTF-8")

# %%
mundo.head()
# Out:
#            pa_s  poblac  densidad  urbana     relig  espvidaf  espvidam  \
# 0     Acerbaján    7400      86.0    54.0  Musulma.        75        67
# 1    Afganistán   20500      25.0    18.0  Musulma.        44        45
# 2      Alemania   81200     227.0    85.0  Protest.        79        73
# 3  Arabia Saudí   18000       7.7    77.0  Musulma.        70        66
# 4     Argentina   33900      12.0    86.0  Católica        75        68
#
#    alfabet  inc_pob  mortinf  pib_cap  regi_n  calor_as     sida  tasa_nat  \
# 0     98.0     1.40     35.0     3000       5       NaN      NaN      23.0
# 1     29.0     2.80    168.0      205       3       NaN      0.0      53.0
# 2     99.0     0.36      6.5    17539       1    3443.0  11179.0      11.0
# 3     62.0     3.20     52.0     6651       5    2874.0     61.0      38.0
# 4     95.0     1.30     25.6     3408       6    3113.0   3904.0      20.0
#
#    tasa_mor   tasasida   log_pib  logtsida   nac_def  fertilid   log_pob  \
# 0       7.0        NaN  3.477121       NaN  3.285714      2.80  3.869232
# 1      22.0   0.000000  2.311754  0.000000  2.409091      6.90  4.311754
# 2      11.0  13.767241  4.244005  1.689544  1.000000      1.47  4.909556
# 3       6.0   0.338889  3.822887  0.805400  6.333333      6.67  4.255273
# 4       9.0  11.516224  3.532500  1.630279  2.222222      2.80  4.530200
#
#    alfabmas  alfabfem  clima  region2
# 0     100.0     100.0    3.0      5.0
# 1      44.0      14.0    3.0      3.0
# 2       NaN       NaN    8.0      1.0
# 3      73.0      48.0    1.0      5.0
# 4      96.0      95.0    8.0      6.0

# %% [markdown]
# # Ejercicio 2

# %% [markdown]
# Hay datos que nos interesa analizar basándonos en agrupaciones, para darle un
# sentido a nuestro análisis en base a esa agrupación. Basándonos en las siguientes
# agrupaciones:

# %% [markdown]
# ### Por Región

# %%
mundo.regi_n.unique()
# Out:
# array([5, 3, 1, 6, 2, 4])

# %%
Regiones = mundo.groupby('regi_n')['pib_cap', 'espvidam', 'alfabet', 'mortinf', 'log_pob'].describe()

# %%
Regiones
# Out:
#        pib_cap                                                                \
#          count          mean          std     min      25%      50%      75%
# regi_n
# 1         21.0  16610.857143  3725.970535  8060.0  15877.0  17245.0  18277.0
# 2         14.0   5159.785714  1708.700819  2340.0   3980.5   5368.0   6635.0
# 3         17.0   4263.000000  6291.046495   202.0    275.0    867.0   6627.0
# 4         19.0    998.684211  1178.257709   122.0    307.5    409.0   1027.5
# 5         17.0   4957.411765  4057.448137   748.0   1500.0   3721.0   6818.0
# 6         21.0   1997.666667  1482.123117   383.0   1078.0   1500.0   2591.0
#
#                 espvidam                                                      \
#             max    count       mean       std   min    25%   50%   75%   max
# regi_n
# 1       23474.0     21.0  73.714286  1.146423  71.0  73.00  74.0  74.0  76.0
# 2        7400.0     14.0  67.714286  2.334641  64.0  66.25  68.5  69.0  72.0
# 3       19860.0     17.0  63.470588  8.725807  45.0  58.00  65.0  68.0  76.0
# 4        4283.0     19.0  50.789474  7.261611  41.0  45.00  51.0  54.5  66.0
# 5       14193.0     17.0  67.352941  3.920159  60.0  65.00  67.0  70.0  76.0
# 6        6950.0     21.0  66.238095  7.334199  43.0  63.00  68.0  71.0  76.0
#
#        alfabet                                                       mortinf  \
#          count       mean        std   min   25%   50%    75%    max   count
# regi_n
# 1         21.0  97.666667   3.366502  85.0  97.0  99.0  99.00  100.0    21.0
# 2         13.0  97.000000   3.763863  86.0  97.0  99.0  99.00   99.0    14.0
# 3         17.0  72.941176  25.168111  29.0  52.0  78.0  91.00   99.0    17.0
# 4         19.0  47.263158  17.863190  18.0  32.5  50.0  57.50   76.0    19.0
# 5         16.0  74.750000  15.872408  48.0  63.5  75.0  83.75   98.0    17.0
# 6         21.0  82.666667  13.484559  53.0  78.0  87.0  93.00   99.0    21.0
#
#                                                                log_pob  \
#              mean        std   min    25%    50%    75%    max   count
# regi_n
# 1        6.910000   1.172220   4.0   6.30    6.8    7.4    9.2    21.0
# 2       16.892857   5.483046   8.7  12.55   18.0   20.6   27.0    14.0
# 3       53.882353  46.441364   4.4  21.70   46.0   79.0  168.0    17.0
# 4       94.178947  28.653186  39.3  75.50  105.0  115.0  137.0    19.0
# 5       41.394118  19.178877   8.6  27.00   39.5   53.0   76.4    17.0
# 6       39.114286  24.524443  10.2  20.30   35.0   52.5  109.0    21.0
#
#
#             mean       std       min       25%       50%       75%       max
# regi_n
# 1       4.115741  0.640604  2.419956  3.716003  4.017033  4.593286  5.416308
# 2       4.010924  0.539278  3.204120  3.669617  3.981114  4.282209  5.173769
# 3       4.723024  0.700803  3.462398  4.311754  4.773786  5.098644  6.081059
# 4       3.989771  0.570941  2.981819  3.648333  3.959041  4.453308  4.991669
# 5       3.899783  0.592374  2.778151  3.558709  3.740363  4.298853  4.816904
# 6       3.973837  0.589401  2.408240  3.716003  3.897627  4.313867  5.194792

# %% [markdown]
# ## Análisis de los datos
#
# Encontramos 6 tipos de regiones enumeradas del 1 al 6:
#
# - La regíon tipo 1 la forman 21 paises.
# - La regíon tipo 2 la forman 14 paises.
# - La regíon tipo 3 la forman 17 paises.
# - La regíon tipo 4 la forman 19 paises.
# - La regíon tipo 5 la forman 17 paises.
# - La regíon tipo 6 la forman 21 paises.

# %% [markdown]
# ##### Pib_cap:
#
# Con respecto al Pib per cápita, las región número 1 es la que mayor produción obtiene anualmente, más del triple que la segunda región con mayor producción (Región número 2).
#
# Lo que nos indica la gran desigualdad entre los seis tipos de regiones.

# %% [markdown]
# #### Esperanza de vida
# La región con mayor esperanza de vida es la región número 1, con 73 años de media, seguida de la región número 2 y 5. La región con menor esperanza de vida es la región número 4, con una diferencia del 46% con respecto a la región Nº1.

# %% [markdown]
# #### Alfabetización
# La distribución de la alfabetización con respecto a las regiones estudiadas es la misma que la esperanza de vida. La región número 1 es la que mayor tasa de alfabetización obtiene en nuestra muestra y la región número 4 es la región con menor tasa de alfabetización.

# %% [markdown]
# #### Mortalidad infaltil
# La mortalidad infantil en la región número 4 es la mayor de toda nuestra muestra, un 1250% más que la región con menor tasa de moratidad infantil que es la región número 1.

# %% [markdown]
# #### Incremento de la población
# Posiblemente es la variable con menores diferencias entre las regiones. La región número 3 es la región con mayor crecimiento en su población, seguido de la región número 1.

# %% [markdown]
# ### Conclusiones finales:
#
# En primer lugar, encontramos grandes diferencias entre las regiones, sobretodo en la variable Pib_cap y en la variable de mortalidad infantil, que representan una distribución inversamente proporcional. Además indica las grandes diferencias entre las regiones con más recursos y las regiones más pobres.
#
# La gran mayoría de las variables estudiadas son medidas incluidas en los índices de desarrollo de cada región a excepción de la tasa de mortalidad infantil. Los paises con más recursos son los que mejores cifras obtienen en las variables socioeconómicas y sociodemográficas, y las que menor tasa de mortalidad representan.

# %% [markdown]
# ### Por Religiones

# %%
mundo.relig.unique()
# Out:
# array([u'Musulma.', u'Protest.', u'Cat\xf3lica', u'Ortodoxa', u'Tribal',
#        u'Animista', u'Budista', u'Taoista', u'Ind\xfa', u'Jud\xeda', nan],
#       dtype=object)

# %%
Religion = mundo.groupby('relig')['pib_cap', 'espvidam', 'alfabet', 'mortinf', 'log_pob'].describe()

# %%
Religion.head()
# Out:
#          pib_cap                                                        \
#            count          mean          std      min      25%      50%
# relig
# Animista     4.0    505.500000   330.568702    263.0    333.5    383.0
# Budista      7.0   6406.571429  7912.046761    230.0    630.0   1800.0
# Católica    41.0   5780.170732  6751.125584    208.0   1078.0   2591.0
# Indú         1.0    275.000000          NaN    275.0    275.0    275.0
# Judía        1.0  13066.000000          NaN  13066.0  13066.0  13066.0
#
#                            espvidam                                         \
#               75%      max    count       mean       std   min   25%   50%
# relig
# Animista    555.0    993.0      4.0  49.250000  6.551081  41.0  45.5  50.5
# Budista   10848.0  19860.0      7.0  66.857143  8.933618  50.0  64.0  67.0
# Católica   7311.0  22384.0     41.0  65.682927  9.535300  41.0  63.0  69.0
# Indú        275.0    275.0      1.0  58.000000       NaN  58.0  58.0  58.0
# Judía     13066.0  13066.0      1.0  76.000000       NaN  76.0  76.0  76.0
#
#                       alfabet                                                 \
#             75%   max   count       mean        std   min    25%   50%   75%
# relig
# Animista  54.25  55.0     4.0  39.500000  15.438048  18.0  34.50  43.0  48.0
# Budista   73.50  76.0     7.0  83.142857  22.512430  35.0  82.50  91.0  96.0
# Católica  73.00  76.0    40.0  84.150000  16.385657  48.0  76.75  89.0  97.0
# Indú      58.00  58.0     1.0  52.000000        NaN  52.0  52.00  52.0  52.0
# Judía     76.00  76.0     1.0  92.000000        NaN  92.0  92.00  92.0  92.0
#
#                mortinf                                                      \
#            max   count        mean        std   min     25%    50%     75%
# relig
# Animista  54.0     4.0  104.500000  18.627936  77.0  101.75  111.5  114.25
# Budista   99.0     7.0   34.000000  38.260728   4.4    5.45   27.7   41.50
# Católica  99.0    41.0   36.253659  33.666579   6.2    9.20   25.2   52.50
# Indú      52.0     1.0   79.000000        NaN  79.0   79.00   79.0   79.00
# Judía     92.0     1.0    8.600000        NaN   8.6    8.60    8.6    8.60
#
#                 log_pob                                                    \
#             max   count      mean       std       min       25%       50%
# relig
# Animista  118.0     4.0  4.013471  0.419096  3.462398  3.865599  4.058636
# Budista   112.0     7.0  4.454921  0.482131  3.763428  4.160530  4.363612
# Católica  117.0    41.0  4.084063  0.463652  3.113943  3.763428  4.017033
# Indú       79.0     1.0  5.959804       NaN  5.959804  5.959804  5.959804
# Judía       8.6     1.0  3.732394       NaN  3.732394  3.732394  3.732394
#
#
#                75%       max
# relig
# Animista  4.206508  4.474216
# Budista   4.818852  5.098644
# Católica  4.450249  5.194792
# Indú      5.959804  5.959804
# Judía     3.732394  3.732394

# %% [markdown]
# ## Análisis de los datos
#
# Encontramos 5 religiones:
#
# - La religión Animista está presente en 4 paises.
# - La religión Budista está presente en 7 paises.
# - La religión Católica está presente en 41 paises.
# - La religión Indú está presente en 1 paises.
# - La religión Judía está presente en 1 paises.

# %% [markdown]
# ##### Pib_cap:
#
# La religión con mayor produción anual es el Judaismo, con casi el doble de PIB que la siguiente religión. La religión con menor capacidad económica es la indú.

# %% [markdown]
# #### Esperanza de vida
# La religión con mayor esperanza de vida es la religión Judía, seguida de la religión budísta y católica. La religión con menor esperanza de vida es la religión Animista.

# %% [markdown]
# #### Alfabetización
# La religión Judía es la que mayor tasa de alfabetización, seguido por el cristianismo y el Budismo. La religión con menor tasa es la religión Animista.

# %% [markdown]
# ### Conclusiones finales:
#
# Al igual que en el apartado anterior y a diferencia de lo que se podría llegar a pensar, las diferencias entre los paises con distintas religiones la rigen los recursos económicos y no los culturales.
#
# Los paises con mayores recursos son los que tienen una representación mayoritaria dentro de su sociedad del Judiaismo, Cristianismo y Budismo. Son los paises con mejores recursos económicos y sociales.

# %% [markdown]
# # Ejercicio Nº4

# %% [markdown]
# Obtén la tasa media de natalidad y mortalidad por clima. Ordena los países en base
# a esas tasas medias (de mayor a menor).

# %%
TasasMedias = mundo.groupby('clima')['tasa_nat','tasa_mor'].mean()

# %%
TasasMedias
# Out:
#         tasa_nat   tasa_mor
# clima
# 1.0    38.428571   7.000000
# 2.0    34.600000   6.000000
# 3.0    29.000000   8.833333
# 4.0    36.800000   9.200000
# 5.0    31.843750  10.387500
# 6.0    25.800000   9.150000
# 7.0    13.750000  11.000000
# 8.0    17.676471  10.008529
# 9.0    13.500000  10.000000

# %%
ClimaPais = mundo.groupby('clima')['pa_s'].describe()

# %%
ClimaPais
# Out:
#       count unique        top freq
# clima
# 1.0       7      7     Egipto    1
# 2.0       5      5   Jordania    1
# 3.0       6      6     México    1
# 4.0       5      5    Bolivia    1
# 5.0      32     32      Haití    1
# 6.0      10     10      India    1
# 7.0       4      4   Lituania    1
# 8.0      34     34   Islandia    1
# 9.0       4      4  Finlandia    1

# %% [markdown]
# Vemos una relación directa entre el tipo de clima y las tasas de natalidad y moralidad. El clima 1 es el que mayor tasa de natalidad y a la vez la menor tasa de mortalidad y el clima 9 es el que menor tasa de natalidad representa y mayor tasa de mortalidad.

# %% [markdown]
# # Ejercicio Nº7

# %%
import seaborn as sns

# %%
swarm = sns.swarmplot(x="clima", y="tasa_nat", hue="regi_n", data=mundo, size = 10)

# %% [markdown]
# ### Análisis
#
# Vemos tres grupos claramente diferenciados, las regiones con una tasa de natalidad inferior al 30%, con una tasa al rededor del 30% y las que tienen una tasa superior al 30%.
#
# - Tasa inferior: Región número 1, número 2 y número 3.
# - Tasa intermedia: Región número 6.
# - Tasa superior: Región número 4 y número 5.
#
# Observamos dos regiones claramente separadas tanto por la variable clima, cómo por la variable natalidad, estas son las regiones número 1 y la región número 4. Gracias al estudio anterior, entre estas regiones la gran diferencia la establece su capacidad económica. Por lo que podemos observar una

# %% [markdown]
# # Ejercicio Nº8

# %%
import matplotlib.pyplot as plt

# %%
NatRegion = mundo[['tasa_nat','clima']]

# %%
NatRegion.head()
# Out:
#    tasa_nat  clima
# 0      23.0    3.0
# 1      53.0    3.0
# 2      11.0    8.0
# 3      38.0    1.0
# 4      20.0    8.0

# %%
boxplot = NatRegion.boxplot(by='clima')

# %% [markdown]
# ### Simetría (estudio de la mediana)
#
# Con respecto a la simetría, el clima 2 y el clima 9 son los climas con una distribución más simétrica por las pequeñas diferencia entre sus medias y medianas.
#
# Cómo distribución sesgada positiva,encontramos los clima 4, 5 y 8, la mayor parte de los datos se encuentran por encima de la mediana, por lo que la media será mayor que la mediana.
#
# Los climas con distribuciones negativas son los climas 1, 3, 6 y 7, puesto que la mayor parte de sus datos se encuentran en la parte inferior, lo que significa que la media es menor que la mediana.

# %% [markdown]
# ### Valores atípicos
#
# Los más importantes los encontramos tanto en el clima 3, cómo en el clima 8. Estos valores son de mucha importancia puesto que pueden indicar eventos únicos o especiales que tendremos que tener en cuenta.
